# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
import numpy as np
from Shapley import ShapNN
from DShap import DShap
import matplotlib.pyplot as plt
import sklearn
from shap_utils import *
# %matplotlib inline
MEM_DIR = './'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# X:\DataShapley\shap_utils.py:180: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   y_true = (y_true - mean)/std
# X:\DataShapley\shap_utils.py:183: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   y = (np.random.random(X.shape[0]) < y_true).astype(int)
# X:\DataShapley\DShap.py:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   self.hidden_units = kwargs.get('hidden_layer_sizes', [])

# %% [markdown]
# Let's have a calssification problem and use the a losigitic regression model for a small data set of size 100.

# %%
problem, model = 'classification', 'logistic'
hidden_units = [] # Empty list in the case of logistic regression.
train_size = 100

# %% [markdown]
# ## Create Synthetic Dataset

# %% [markdown]
# Let's create a synthetic data set with input-output $y = Bernouli(f(x))$ where $f$ is a polynomial of oder 'difficulty' and $x \in \mathscr{R}^d$. ('important_dims' determines the number of $d$ dimensions in $x$ that are non-null)

# %%
d, difficulty = 50, 1
num_classes = 2
tol = 0.03
target_accuracy = 0.7
important_dims = 5
clf = return_model(model, solver='liblinear', hidden_units=tuple(hidden_units))
_param = 1.0
for _ in range(100):
    X_raw = np.random.multivariate_normal(mean=np.zeros(d), cov = np.eye(d), 
                                          size=train_size + 5000)
    _, y_raw, _, _ = label_generator(
        problem, X_raw, param = _param,  difficulty = difficulty, important=important_dims)
    clf.fit(X_raw[:train_size], y_raw[:train_size])
    test_acc = clf.score(X_raw[train_size:], y_raw[train_size:])
    if test_acc > target_accuracy:
        break
    _param *= 1.1
print('Performance using the whole training set = {0:.2f}'.format(test_acc))
# Out:
# Performance using the whole training set = 0.72

# %% [markdown]
# ## Running

# %% [markdown]
# Now let's create the instance that takes cares of computing all the algorithms for the data set. Here we run it several times one-after-another, but in a real-world scenario they could be run in parallel.

# %%
X, y = X_raw[:train_size], y_raw[:train_size]
X_test, y_test = X_raw[train_size:], y_raw[train_size:]
model = 'logistic'
problem = 'classification'
num_test = 1000
directory = './temp'
dshap = DShap(X, y, X_test, y_test, num_test, 
              sources=None, 
              sample_weight=None,
              model_family=model, 
              metric='accuracy',
              overwrite=True,
              directory=directory, seed=0)
dshap.run(100, 0.1, g_run=False)
# Out:
# X:\DataShapley\DShap.py:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.model_family is 'logistic':
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8292/376113169.py in <module>
#       5 num_test = 1000
#       6 directory = './temp'
# ----> 7 dshap = DShap(X, y, X_test, y_test, num_test,
#       8               sources=None,
#       9               sample_weight=None,
#
# X:\DataShapley\DShap.py in __init__(self, X, y, X_test, y_test, num_test, sources, sample_weight, directory, problem, model_family, metric, seed, overwrite, **kwargs)
#      62         if self.directory is not None:
#      63             if overwrite and os.path.exists(directory):
# ---> 64                 tf.io.gfile.DeleteRecursively(directory)
#      65             if not os.path.exists(directory):
#      66                 os.makedirs(directory)
#
# AttributeError: module 'tensorflow._api.v2.io.gfile' has no attribute 'DeleteRecursively'

# %%
tf.io.gfile.re

# %%
X, y = X_raw[:100], y_raw[:100]
X_test, y_test = X_raw[100:], y_raw[100:]
model = 'logistic'
problem = 'classification'
num_test = 1000
directory = './temp'
dshap = DShap(X, y, X_test, y_test, num_test, model_family=model, metric='accuracy',
              directory=directory, seed=1)
dshap.run(100, 0.1)

# %%
X, y = X_raw[:100], y_raw[:100]
X_test, y_test = X_raw[100:], y_raw[100:]
model = 'logistic'
problem = 'classification'
num_test = 1000
directory = './temp'
dshap = DShap(X, y, X_test, y_test, num_test, model_family=model, metric='accuracy',
              directory=directory, seed=2)
dshap.run(100, 0.1)

# %% [markdown]
# Now we merge results for the parallel runs:

# %%
dshap.merge_results()
# Out:
# ./temp\mem_tmc_0000.pkl
# ./temp\mem_g_0000.pkl

# %% [markdown]
# Let's look at the convergence plots of the algorithms.

# %%
convergence_plots(dshap.marginals_tmc)

# %%
convergence_plots(dshap.marginals_g)

# %% [markdown]
# Now let's see the effect of removing high valuen points

# %%
dshap.performance_plots([dshap.vals_tmc, dshap.vals_g, dshap.vals_loo], num_plot_markers=20,
                       sources=dshap.sources)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8292/3066916354.py in <module>
# ----> 1 dshap.performance_plots([dshap.vals_tmc, dshap.vals_g, dshap.vals_loo], num_plot_markers=20,
#       2                        sources=dshap.sources)
#
# AttributeError: 'DShap' object has no attribute 'vals_g'

# %%
dshap.performance_plots([dshap.vals_tmc], num_plot_markers=20,
                        sources=dshap.sources)
